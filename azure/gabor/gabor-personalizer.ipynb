# %%
#%pip install azure-cognitiveservices-personalizer

# %%
from azure.cognitiveservices.personalizer import PersonalizerClient
from azure.cognitiveservices.personalizer.models import RankableAction, RewardRequest, RankRequest
from msrest.authentication import CognitiveServicesCredentials

import datetime, json, os, time, uuid, random

key = "f1130e13ee63442d80c1cbbd34323f9a"
endpoint = "https://personalizer-1.cognitiveservices.azure.com/"

# Instantiate a Personalizer client
client = PersonalizerClient(endpoint, CognitiveServicesCredentials(key))

actions_and_features = {
    'pasta': {
        'brand_info': {
            'company':'pasta_inc'
        },
        'attributes': {
            'qty':1, 'cuisine':'italian',
            'price':12
        },
        'dietary_attributes': {
            'vegan': False,
            'low_carb': False,
            'high_protein': False,
            'vegetarian': False,
            'low_fat': True,
            'low_sodium': True
        }
    },
    'bbq': {
        'brand_info' : {
            'company': 'ambisco'
        },
        'attributes': {
            'qty': 2,
            'category': 'bbq',
            'price': 20
        },
        'dietary_attributes': {
            'vegan': False,
            'low_carb': True,
            'high_protein': True,
            'vegetarian': False,
            'low_fat': False,
            'low_sodium': False
        }
    },
    'bao': {
        'brand_info': {
            'company': 'bao_and_co'
        },
        'attributes': {
            'qty': 4,
            'category': 'chinese',
            'price': 8
        },
        'dietary_attributes': {
            'vegan': False,
            'low_carb': True,
            'high_protein': True,
            'vegetarian': False,
            'low_fat': True,
            'low_sodium': False
        }
    },
    'hummus': {
        'brand_info' : {
            'company': 'garbanzo_inc'
        },
        'attributes' : {
            'qty': 1,
            'category': 'breakfast',
            'price': 5
        },
        'dietary_attributes': {
            'vegan': True,
            'low_carb': False,
            'high_protein': True,
            'vegetarian': True,
            'low_fat': False,
            'low_sodium': False
        }
    },
    'veg_platter': {
        'brand_info': {
            'company': 'farm_fresh'
        },
        'attributes': {
            'qty': 1,
            'category': 'produce',
            'price': 7
        },
        'dietary_attributes': {
            'vegan': True,
            'low_carb': True,
            'high_protein': False,
            'vegetarian': True,
            'low_fat': True,
            'low_sodium': True
        }
    }
}

def get_actions():
    res = []
    for action_id, feat in actions_and_features.items():
        action = RankableAction(id=action_id, features=[feat])
        res.append(action)
    return res

user_profiles = {
    'Bill': {
        'dietary_preferences': 'low_carb',
        'avg_order_price': '0-20',
        'browser_type': 'edge'
    },
    'Satya': {
        'dietary_preferences': 'low_sodium',
        'avg_order_price': '201+',
        'browser_type': 'safari'
    },
    'Amy': {
        'dietary_preferences': {
            'vegan', 'vegetarian'
        },
        'avg_order_price': '21-50',
        'browser_type': 'edge'},
}

def get_context(user):
    location_context = {'location': random.choice(['west', 'east', 'midwest'])}
    time_of_day = {'time_of_day': random.choice(['morning', 'afternoon', 'evening'])}
    app_type = {'application_type': random.choice(['edge', 'safari', 'edge_mobile', 'mobile_app'])}
    res = [user_profiles[user], location_context, time_of_day, app_type]
    return res

def get_random_users(k = 5):
    return random.choices(list(user_profiles.keys()), k=k)


def get_reward_score(user, actionid, context):
    reward_score = 0.0
    action = actions_and_features[actionid]

    if user == 'Bill':
        if action['attributes']['price'] < 10 and (context[1]['location'] !=  "midwest"):
            reward_score = 1.0
            print("Bill likes to be economical when he's not in the midwest visiting his friend Warren. He bought", actionid, "because it was below a price of $10.")
        elif (action['dietary_attributes']['low_carb'] == True) and (context[1]['location'] ==  "midwest"):
            reward_score = 1.0
            print("Bill is visiting his friend Warren in the midwest. There he's willing to spend more on food as long as it's low carb, so Bill bought" + actionid + ".")

        elif (action['attributes']['price'] >= 10) and (context[1]['location'] != "midwest"):
            print("Bill didn't buy", actionid, "because the price was too high when not visting his friend Warren in the midwest.")

        elif (action['dietary_attributes']['low_carb'] == False) and (context[1]['location'] ==  "midwest"):
            print("Bill didn't buy", actionid, "because it's not low-carb, and he's in the midwest visitng his friend Warren.")

    elif user == 'Satya':
        if action['dietary_attributes']['low_sodium'] == True:
            reward_score = 1.0
            print("Satya is health conscious, so he bought", actionid,"since it's low in sodium.")
        else:
            print("Satya did not buy", actionid, "because it's not low sodium.")

    elif user == 'Amy':
        if (action['dietary_attributes']['vegan'] == True) or (action['dietary_attributes']['vegetarian'] == True):
            reward_score = 1.0
            print("Amy likes to eat plant-based foods, so she bought", actionid, "because it's vegan or vegetarian friendly.")
        else:
            print("Amy did not buy", actionid, "because it's not vegan or vegetarian.")

    return reward_score

# %%
def run_personalizer_cycle():
    actions = get_actions()
    user_list = get_random_users()
    for user in user_list:
        print("------------")
        print("User:", user, "\n")
        context = get_context(user)
        print("Context:", context, "\n")

        rank_request = RankRequest(actions=actions, context_features=context)
        response = client.rank(rank_request=rank_request)
        print("Rank API response:", response, "\n")

        eventid = response.event_id
        actionid = response.reward_action_id
        print("Personalizer recommended action", actionid, "and it was shown as the featured product.\n")

        reward_score = get_reward_score(user, actionid, context)
        client.events.reward(event_id=eventid, value=reward_score)
        print("\nA reward score of", reward_score , "was sent to Personalizer.")
        print("------------\n")

continue_loop = True
while continue_loop:
    run_personalizer_cycle()

    br = input("Press Q to exit, or any other key to run another loop: ")
    if(br.lower()=='q'):
        continue_loop = False
# Out:
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'afternoon'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408ac0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408730>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408790>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408ca0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a83d4c0>], 'event_id': '929a10727e8d400fa36b07ae82e5514b-c02BF', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Bill is visiting his friend Warren in the midwest. There he's willing to spend more on food as long as it's low carb, so Bill boughtveg_platter.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'afternoon'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e2490>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e2130>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b149f70>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b149640>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c910>], 'event_id': 'b611322fcc2f4c44971a972bb294dc4b-c02BH', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Bill likes to be economical when he's not in the midwest visiting his friend Warren. He bought veg_platter because it was below a price of $10.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'afternoon'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c490>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46ce80>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cb20>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c4c0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53c0a0>], 'event_id': '7921decf37b74c1babd5bb49bf68ae48-c02BI', 'reward_action_id': 'hummus'}
#
# Personalizer recommended action hummus and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought hummus because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'morning'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c940>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cd30>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cac0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c760>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c340>], 'event_id': '84022a7ee8b146e7ac1e80cf7cee3565-c02BJ', 'reward_action_id': 'hummus'}
#
# Personalizer recommended action hummus and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought hummus because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'morning'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e2460>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e2160>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b0a6b50>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b3d2760>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408820>], 'event_id': '68eac24fdb184f51a198d0b9b5923259-c02BK', 'reward_action_id': 'pasta'}
#
# Personalizer recommended action pasta and it was shown as the featured product.
#
# Bill didn't buy pasta because the price was too high when not visting his friend Warren in the midwest.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------

# %%
for i in range(0,1000):
    run_personalizer_cycle()
# Out:
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'midwest'}, {'time_of_day': 'morning'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a840100>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e280>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e700>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e070>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e340>], 'event_id': 'c908d717023c4661814cd18c46ab034d-c02CA', 'reward_action_id': 'hummus'}
#
# Personalizer recommended action hummus and it was shown as the featured product.
#
# Satya did not buy hummus because it's not low sodium.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'evening'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7400>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c72b0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7e20>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7520>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cf10>], 'event_id': '4e8de624b96342939256f5e10eebc401-c02CB', 'reward_action_id': 'bbq'}
#
# Personalizer recommended action bbq and it was shown as the featured product.
#
# Amy did not buy bbq because it's not vegan or vegetarian.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'east'}, {'time_of_day': 'evening'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a83d670>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a83dc10>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a83de50>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b583220>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b5831c0>], 'event_id': '5843b932e6bd4266ae3902ce0c1fe359-c02CC', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'evening'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b5833a0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b583280>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b583700>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b5835b0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b583520>], 'event_id': 'd310241a6d484abaaafdce5e65db9441-c02CD', 'reward_action_id': 'pasta'}
#
# Personalizer recommended action pasta and it was shown as the featured product.
#
# Amy did not buy pasta because it's not vegan or vegetarian.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'west'}, {'time_of_day': 'afternoon'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b583a00>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b583e20>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b583e50>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b5838e0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b5835e0>], 'event_id': '039fc329ed14405399124bad7828689a-c02CD', 'reward_action_id': 'pasta'}
#
# Personalizer recommended action pasta and it was shown as the featured product.
#
# Satya is health conscious, so he bought pasta since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'midwest'}, {'time_of_day': 'morning'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7fa0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7dc0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7460>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7640>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a840100>], 'event_id': '675d26bc3f2e4f4f85be6475ba1c7236-c02CE', 'reward_action_id': 'bbq'}
#
# Personalizer recommended action bbq and it was shown as the featured product.
#
# Satya did not buy bbq because it's not low sodium.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'east'}, {'time_of_day': 'afternoon'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e370>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e940>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a83d430>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a83df40>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a83d700>], 'event_id': 'f59670a5cfa342479f27e51477b5aaeb-c02CF', 'reward_action_id': 'bbq'}
#
# Personalizer recommended action bbq and it was shown as the featured product.
#
# Satya did not buy bbq because it's not low sodium.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'morning'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408cd0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408be0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4088b0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408e80>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b3ec400>], 'event_id': 'b65c76ebedd5408db90c437d1db7c464-c02CG', 'reward_action_id': 'bao'}
#
# Personalizer recommended action bao and it was shown as the featured product.
#
# Amy did not buy bao because it's not vegan or vegetarian.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'evening'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cdc0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c700>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cfd0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cc10>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cf40>], 'event_id': 'c90ea0aff6d74907b50b4b2a89f0b84c-c02CG', 'reward_action_id': 'pasta'}
#
# Personalizer recommended action pasta and it was shown as the featured product.
#
# Amy did not buy pasta because it's not vegan or vegetarian.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'west'}, {'time_of_day': 'morning'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b0a6f10>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408850>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408eb0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408790>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4088e0>], 'event_id': '0aa214e2eb7b4d78b441f34f353be09a-c02CH', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'evening'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e640>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e310>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e520>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e7f0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e820>], 'event_id': '7a982473b6154916bc98a6d4a0bdcfdc-c02CI', 'reward_action_id': 'hummus'}
#
# Personalizer recommended action hummus and it was shown as the featured product.
#
# Bill didn't buy hummus because it's not low-carb, and he's in the midwest visitng his friend Warren.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'west'}, {'time_of_day': 'morning'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a834670>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a8343d0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a83dbe0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a83d670>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a83dc40>], 'event_id': '0d8c530a24074699be4b08f9b2abc25f-c02CJ', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'morning'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cdf0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c7f0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c640>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c1f0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cfd0>], 'event_id': 'f7ce4824453e490d889534e102ab940e-c02CK', 'reward_action_id': 'hummus'}
#
# Personalizer recommended action hummus and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought hummus because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'morning'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d820>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d7f0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d280>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d370>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d400>], 'event_id': '0358b8bdc725404f9c26433ed3ec79ca-c02CK', 'reward_action_id': 'hummus'}
#
# Personalizer recommended action hummus and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought hummus because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'evening'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a834460>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7d60>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7fa0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7310>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7eb0>], 'event_id': '79bb3182ae6444dd8d528940d623286c-c02CL', 'reward_action_id': 'bbq'}
#
# Personalizer recommended action bbq and it was shown as the featured product.
#
# Amy did not buy bbq because it's not vegan or vegetarian.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'evening'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e5b0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e4c0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e310>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e280>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e2e0>], 'event_id': 'd21f75f1bf1b491eaaa0c48135bc4fac-c02CM', 'reward_action_id': 'hummus'}
#
# Personalizer recommended action hummus and it was shown as the featured product.
#
# Bill didn't buy hummus because it's not low-carb, and he's in the midwest visitng his friend Warren.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'west'}, {'time_of_day': 'afternoon'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e24c0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e2400>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cb20>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cdf0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46ca60>], 'event_id': 'bc7ff656e635426d9b6ae9806e78da49-c02CN', 'reward_action_id': 'bao'}
#
# Personalizer recommended action bao and it was shown as the featured product.
#
# Satya did not buy bao because it's not low sodium.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'morning'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c3a0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c280>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c850>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408c70>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408af0>], 'event_id': 'd33234f193ff4009b0daa0a49dae4833-c02CR', 'reward_action_id': 'bbq'}
#
# Personalizer recommended action bbq and it was shown as the featured product.
#
# Bill didn't buy bbq because the price was too high when not visting his friend Warren in the midwest.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'east'}, {'time_of_day': 'morning'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53dc70>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d280>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d6d0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d370>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d430>], 'event_id': 'edf20977a9724eb3a12b1e8c30be598a-c02CS', 'reward_action_id': 'bao'}
#
# Personalizer recommended action bao and it was shown as the featured product.
#
# Satya did not buy bao because it's not low sodium.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'evening'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408d00>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408d60>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408a00>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a826760>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e2430>], 'event_id': 'fcc7ab5420e44eae8f0824bc21bb20bb-c02CS', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Bill likes to be economical when he's not in the midwest visiting his friend Warren. He bought veg_platter because it was below a price of $10.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'evening'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e9d0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e370>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e730>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e940>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e400>], 'event_id': '4c02ea34e2ad41b3858c86e45c79c2bc-c02CT', 'reward_action_id': 'hummus'}
#
# Personalizer recommended action hummus and it was shown as the featured product.
#
# Bill likes to be economical when he's not in the midwest visiting his friend Warren. He bought hummus because it was below a price of $10.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'west'}, {'time_of_day': 'afternoon'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7e20>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7cd0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7eb0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7550>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7d90>], 'event_id': '1b661b6e441c492c8c55b3f4b2a4aab8-c02CU', 'reward_action_id': 'bbq'}
#
# Personalizer recommended action bbq and it was shown as the featured product.
#
# Satya did not buy bbq because it's not low sodium.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'morning'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cc40>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c760>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c9a0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cee0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c5e0>], 'event_id': '65cc358899de43218072505eb108d55e-c02CV', 'reward_action_id': 'pasta'}
#
# Personalizer recommended action pasta and it was shown as the featured product.
#
# Amy did not buy pasta because it's not vegan or vegetarian.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'evening'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d220>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d7f0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53dc10>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d6d0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d5b0>], 'event_id': '83cdc1300aed4d82b1ccb826fa77c412-c02CW', 'reward_action_id': 'bbq'}
#
# Personalizer recommended action bbq and it was shown as the featured product.
#
# Bill didn't buy bbq because the price was too high when not visting his friend Warren in the midwest.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'evening'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x10778dd00>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7430>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7550>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7ee0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7eb0>], 'event_id': 'e80d3bc2b4fa46cea21d68c93e2f3297-c02CX', 'reward_action_id': 'bbq'}
#
# Personalizer recommended action bbq and it was shown as the featured product.
#
# Bill didn't buy bbq because the price was too high when not visting his friend Warren in the midwest.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'evening'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e1f0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e250>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e370>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e3a0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e640>], 'event_id': '3707bdb69a3d4b0fa9cf41dbe1221db0-c02CX', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought veg_platter because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'evening'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e2130>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e2160>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46ce80>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c490>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cc40>], 'event_id': '37c6e8265e3c4269be2c8214952a87fc-c02CY', 'reward_action_id': 'pasta'}
#
# Personalizer recommended action pasta and it was shown as the featured product.
#
# Bill didn't buy pasta because the price was too high when not visting his friend Warren in the midwest.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'evening'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c2b0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c1f0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cca0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408790>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408d60>], 'event_id': '0ea88c177c1f44ecb31c2bbcb81c3f71-c02CZ', 'reward_action_id': 'hummus'}
#
# Personalizer recommended action hummus and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought hummus because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'midwest'}, {'time_of_day': 'evening'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d2b0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d6d0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53dc10>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53dc40>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d5b0>], 'event_id': '6a7e5126fd4c4fc190771ff37f1fa249-c02D0', 'reward_action_id': 'pasta'}
#
# Personalizer recommended action pasta and it was shown as the featured product.
#
# Satya is health conscious, so he bought pasta since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'afternoon'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408ca0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408880>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a826760>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a826a30>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e2910>], 'event_id': '024340d966cc4bac93816f0cb341aa5b-c02D1', 'reward_action_id': 'bbq'}
#
# Personalizer recommended action bbq and it was shown as the featured product.
#
# Amy did not buy bbq because it's not vegan or vegetarian.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'east'}, {'time_of_day': 'evening'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e0d0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e820>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e550>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e2e0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e310>], 'event_id': '458153000f38433b83bfcc357904fa43-c02D1', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'evening'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7cd0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7370>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c73d0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7520>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7f70>], 'event_id': '3662fe95f30b487a9e3157c1ca7adfbe-c02D2', 'reward_action_id': 'bao'}
#
# Personalizer recommended action bao and it was shown as the featured product.
#
# Amy did not buy bao because it's not vegan or vegetarian.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'afternoon'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c460>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46ce50>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c130>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cf70>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c850>], 'event_id': 'b077aedddf294c7cb4110d5ab27ed3bb-c02D4', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought veg_platter because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'evening'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d9a0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d3d0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d490>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53dc40>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d370>], 'event_id': 'a8a667f9e0fc4336b181c9fca1ae013d-c02D5', 'reward_action_id': 'pasta'}
#
# Personalizer recommended action pasta and it was shown as the featured product.
#
# Amy did not buy pasta because it's not vegan or vegetarian.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'morning'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7310>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7220>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7cd0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7fd0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c73d0>], 'event_id': '30b6df8e30e2400eb1a62675524f2442-c02D6', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought veg_platter because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'midwest'}, {'time_of_day': 'morning'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e790>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e0a0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e700>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e3d0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e6a0>], 'event_id': '984e2d94a1c44d27aad41f9cfaada1ed-c02D7', 'reward_action_id': 'bbq'}
#
# Personalizer recommended action bbq and it was shown as the featured product.
#
# Satya did not buy bbq because it's not low sodium.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'afternoon'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e2460>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e2100>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cfd0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c9a0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c460>], 'event_id': 'eec9352a84a54c8f8ff19be117665cfd-c02D7', 'reward_action_id': 'bbq'}
#
# Personalizer recommended action bbq and it was shown as the featured product.
#
# Amy did not buy bbq because it's not vegan or vegetarian.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'evening'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cdc0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cee0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c3a0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408d00>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408a30>], 'event_id': '2dc87940a8bd44a1b584092344ae7df5-c02Db', 'reward_action_id': 'bbq'}
#
# Personalizer recommended action bbq and it was shown as the featured product.
#
# Amy did not buy bbq because it's not vegan or vegetarian.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'west'}, {'time_of_day': 'evening'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53db80>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d8e0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53dbb0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53dc40>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53db50>], 'event_id': '9205ce18428c4411ab112cd7e7e17cba-c02Dc', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'east'}, {'time_of_day': 'morning'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408df0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408cd0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a826ca0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e2490>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e2160>], 'event_id': '95352463e71142be97e6938ac2876f15-c02De', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'east'}, {'time_of_day': 'morning'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e610>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e160>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e130>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e1f0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e250>], 'event_id': '183bee62f3e6434b97e44466cafa73fc-c02Df', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'east'}, {'time_of_day': 'afternoon'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7160>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c73a0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7cd0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7370>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b4c7100>], 'event_id': 'd314cf98435242bebde92a2947ab4b94-c02Df', 'reward_action_id': 'pasta'}
#
# Personalizer recommended action pasta and it was shown as the featured product.
#
# Satya is health conscious, so he bought pasta since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'morning'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cc40>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c3a0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c910>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46cf40>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b46c1f0>], 'event_id': '6acebd9fe7dd4c4a9e28b83b17cda52a-c02Dg', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought veg_platter because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'west'}, {'time_of_day': 'evening'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d1f0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53db50>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53dbb0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d820>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53d610>], 'event_id': 'b4c5422c542a41fc98c4610baa5ca00a-c02Dh', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# ...
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'evening'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408eb0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408820>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408ee0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408d00>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b53da60>], 'event_id': '4c985c2507484a86abbcd104c3fdb317-c02Fe', 'reward_action_id': 'hummus'}
#
# Personalizer recommended action hummus and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought hummus because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'evening'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b3ec130>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408970>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408dc0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408ca0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b408be0>], 'event_id': '4e84e6d658b546fda641b8e9c020b67a-c02Ff', 'reward_action_id': 'hummus'}
#
# Personalizer recommended action hummus and it was shown as the featured product.
#
# Bill didn't buy hummus because it's not low-carb, and he's in the midwest visitng his friend Warren.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'east'}, {'time_of_day': 'morning'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b3e8f40>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13a3e2430>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b3d23d0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50e310>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x13b50ea00>], 'event_id': 'b4da6da2ed2949ee9841f814e546ff5e-c02Fg', 'reward_action_id': 'hummus'}
#
# Personalizer recommended action hummus and it was shown as the featured product.
#
# Satya did not buy hummus because it's not low sodium.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 for i in range(0,1000):
# ----> 2     run_personalizer_cycle()
#
# Cell In[16], line 19, in run_personalizer_cycle()
#      16 print("Personalizer recommended action", actionid, "and it was shown as the featured product.\n")
#      18 reward_score = get_reward_score(user, actionid, context)
# ---> 19 client.events.reward(event_id=eventid, value=reward_score)
#      20 print("\nA reward score of", reward_score , "was sent to Personalizer.")
#      21 print("------------\n")
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/azure/cognitiveservices/personalizer/operations/events_operations.py:81, in EventsOperations.reward(self, event_id, value, custom_headers, raw, **operation_config)
#      79 # Construct and send request
#      80 request = self._client.post(url, query_parameters, header_parameters, body_content)
# ---> 81 response = self._client.send(request, stream=False, **operation_config)
#      83 if response.status_code not in [204]:
#      84     raise HttpOperationError(self._deserialize, response)
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/msrest/service_client.py:336, in ServiceClient.send(self, request, headers, content, **kwargs)
#     334 kwargs.setdefault('stream', True)
#     335 try:
# --> 336     pipeline_response = self.config.pipeline.run(request, **kwargs)
#     337     # There is too much thing that expects this method to return a "requests.Response"
#     338     # to break it in a compatible release.
#     339     # Also, to be pragmatic in the "sync" world "requests" rules anyway.
#     340     # However, attach the Universal HTTP response
#     341     # to get the streaming generator.
#     342     response = pipeline_response.http_response.internal_response
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/msrest/pipeline/__init__.py:197, in Pipeline.run(self, request, **kwargs)
#     195 pipeline_request = Request(request, context)  # type: Request[HTTPRequestType]
#     196 first_node = self._impl_policies[0] if self._impl_policies else self._sender
# --> 197 return first_node.send(pipeline_request, **kwargs)
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/msrest/pipeline/__init__.py:150, in _SansIOHTTPPolicyRunner.send(self, request, **kwargs)
#     148 self._policy.on_request(request, **kwargs)
#     149 try:
# --> 150     response = self.next.send(request, **kwargs)
#     151 except Exception:
#     152     if not self._policy.on_exception(request, **kwargs):
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/msrest/pipeline/requests.py:72, in RequestsCredentialsPolicy.send(self, request, **kwargs)
#      70 try:
#      71     try:
# ---> 72         return self.next.send(request, **kwargs)
#      73     except (oauth2.rfc6749.errors.InvalidGrantError,
#      74             oauth2.rfc6749.errors.TokenExpiredError) as err:
#      75         error = "Token expired or is invalid. Attempting to refresh."
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/msrest/pipeline/requests.py:137, in RequestsPatchSession.send(self, request, **kwargs)
#     134         session.adapters[protocol].max_retries = max_retries
#     136 try:
# --> 137     return self.next.send(request, **kwargs)
#     138 finally:
#     139     if old_max_redirects:
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/msrest/pipeline/__init__.py:150, in _SansIOHTTPPolicyRunner.send(self, request, **kwargs)
#     148 self._policy.on_request(request, **kwargs)
#     149 try:
# --> 150     response = self.next.send(request, **kwargs)
#     151 except Exception:
#     152     if not self._policy.on_exception(request, **kwargs):
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/msrest/pipeline/requests.py:193, in PipelineRequestsHTTPSender.send(self, request, **kwargs)
#     188 if request.context.session is not self.driver.session:
#     189     kwargs['session'] = request.context.session
#     191 return Response(
#     192     request,
# --> 193     self.driver.send(request.http_request, **kwargs)
#     194 )
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/msrest/universal_http/requests.py:333, in RequestsHTTPSender.send(self, request, **kwargs)
#     314 """Send request object according to configuration.
#     315
#     316 Available kwargs:
#    (...)
#     330 :param ClientRequest request: The request object to be sent.
#     331 """
#     332 requests_kwargs = self._configure_send(request, **kwargs)
# --> 333 return super(RequestsHTTPSender, self).send(request, **requests_kwargs)
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/msrest/universal_http/requests.py:139, in BasicRequestsHTTPSender.send(self, request, **kwargs)
#     137 session = kwargs.pop('session', self.session)
#     138 try:
# --> 139     response = session.request(
#     140         request.method,
#     141         request.url,
#     142         **kwargs)
#     143 except requests.RequestException as err:
#     144     msg = "Error occurred in request."
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/ssl.py:501, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     495 def wrap_socket(self, sock, server_side=False,
#     496                 do_handshake_on_connect=True,
#     497                 suppress_ragged_eofs=True,
#     498                 server_hostname=None, session=None):
#     499     # SSLSocket class handles server_hostname encoding before it calls
#     500     # ctx._wrap_socket()
# --> 501     return self.sslsocket_class._create(
#     502         sock=sock,
#     503         server_side=server_side,
#     504         do_handshake_on_connect=do_handshake_on_connect,
#     505         suppress_ragged_eofs=suppress_ragged_eofs,
#     506         server_hostname=server_hostname,
#     507         context=self,
#     508         session=session
#     509     )
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/ssl.py:1041, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038         if timeout == 0.0:
#    1039             # non-blocking
#    1040             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041         self.do_handshake()
#    1042 except (OSError, ValueError):
#    1043     self.close()
#
# File ~/miniconda3/envs/m1-master-thesis/lib/python3.9/ssl.py:1310, in SSLSocket.do_handshake(self, block)
#    1308     if timeout == 0.0 and block:
#    1309         self.settimeout(None)
# -> 1310     self._sslobj.do_handshake()
#    1311 finally:
#    1312     self.settimeout(timeout)
#
# KeyboardInterrupt:
